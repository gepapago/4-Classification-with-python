# %% [markdown]
# #  Classification of tumors with Support Vector Machines (Hyperparameter tunning)
# ### We want to try Support Vector Machines, but we have no idea what hyperparameters we should use. So we define a structure with the values ​​we want to test for each hyperparameter.

# %%
from sklearn import datasets
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# * Let's get back to the problem with biopsies and breast cancer.

# %%
bc = datasets.load_breast_cancer(as_frame=True)
bc.data
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
param_grid = [
    {
        "kernel": ["rbf"], 
        "gamma": [1e-2, 1e-3, 1e-4], 
        "C": [1, 10, 100, 1000],
        "decision_function_shape": ["ovo", "ovr"]
    },
    {
        "kernel": ["linear"], 
        "C": [1, 10, 100, 1000],
        "decision_function_shape": ["ovo", "ovr"]
    },
]

# %% [markdown]
# * Next, we use the `GridSearchCV` class, which will try all possible combinations of the parameters and find the best model.
#
# * `GridSearchCV', as its name says, also performs $k$-fold validation, where $k = 5$ unless we define something else.
#
# * Also, like other scikit-learn methods that support parallelization, with the `n_jobs` parameter we ask for the number of parallel processes we want to run (-1 means as many as possible).

# %%
clf = SVC()
grid_search = GridSearchCV(clf, param_grid=param_grid, n_jobs=-1)
grid_search.fit(bc.data, bc.target)
# Out:
# GridSearchCV(estimator=SVC(), n_jobs=-1,
#              param_grid=[{'C': [1, 10, 100, 1000],
#                           'decision_function_shape': ['ovo', 'ovr'],
#                           'gamma': [0.01, 0.001, 0.0001], 'kernel': ['rbf']},
#                          {'C': [1, 10, 100, 1000],
#                           'decision_function_shape': ['ovo', 'ovr'],
#                           'kernel': ['linear']}])

# %% [markdown]
# * Next, we use the `GridSearchCV` class, which will try all possible combinations of the parameters and find the best model.
#
# * `GridSearchCV', as its name says, also performs $k$-fold validation, where $k = 5$ unless we define something else.
#
# * Also, like other scikit-learn methods that support parallelization, with the `n_jobs` parameter we ask for the number of parallel processes we want to run (-1 means as many as possible).

# %%
grid_search.best_params_
# Out:
# {'C': 100, 'decision_function_shape': 'ovo', 'kernel': 'linear'}

# %% [markdown]
# * If we want to get the best model to use, this is available from the `best_estimator_` property.

# %%
grid_search.best_estimator_
# Out:
# SVC(C=100, decision_function_shape='ovo', kernel='linear')

# %% [markdown]
# * If we want to see all the results, we can get them with the `cv_results_` property.

# %%
grid_search_results = pd.DataFrame(grid_search.cv_results_)
print(grid_search_results.shape)
grid_search_results
# Out:
# (32, 17)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.034367      0.002893         0.018493        0.003409       1
# 1        0.027807      0.001518         0.012188        0.002316       1
# 2        0.015840      0.001400         0.007788        0.000753       1
# 3        0.032065      0.001456         0.014848        0.000780       1
# 4        0.026748      0.002187         0.011573        0.001273       1
# 5        0.014390      0.000290         0.007980        0.000580       1
# 6        0.032557      0.001228         0.016269        0.000680      10
# 7        0.027339      0.001334         0.010299        0.001004      10
# 8        0.013677      0.001300         0.006487        0.001484      10
# 9        0.027278      0.000304         0.012535        0.001342      10
# 10       0.023679      0.000551         0.008479        0.001009      10
# 11       0.012509      0.001108         0.005321        0.000590      10
# 12       0.019892      0.000899         0.011764        0.000419     100
# 13       0.019349      0.000812         0.008924        0.000821     100
# 14       0.012212      0.000722         0.005215        0.000110     100
# 15       0.019521      0.000680         0.011933        0.000733     100
# 16       0.019701      0.001167         0.007717        0.001097     100
# 17       0.012243      0.000993         0.004748        0.000350     100
# 18       0.020977      0.000985         0.011823        0.000427    1000
# 19       0.019858      0.001725         0.008760        0.000604    1000
# 20       0.018306      0.003070         0.005644        0.000746    1000
# 21       0.023064      0.000410         0.013053        0.001162    1000
# 22       0.021807      0.001404         0.008352        0.000756    1000
# 23       0.018605      0.004129         0.005171        0.000307    1000
# 24       2.078829      0.843934         0.002588        0.000359       1
# 25       2.088413      0.840969         0.002672        0.000415       1
# 26       6.894012      1.496287         0.002854        0.000383      10
# 27       6.902102      1.274604         0.003198        0.000837      10
# 28      13.753024      2.014074         0.002387        0.000601     100
# 29      13.012354      6.133496         0.001773        0.000196     100
# 30      13.373683      9.776557         0.002199        0.000617    1000
# 31      11.413814      8.383838         0.002977        0.001363    1000
#
#    param_decision_function_shape param_gamma param_kernel  \
# 0                            ovo        0.01          rbf
# 1                            ovo       0.001          rbf
# 2                            ovo      0.0001          rbf
# 3                            ovr        0.01          rbf
# 4                            ovr       0.001          rbf
# 5                            ovr      0.0001          rbf
# 6                            ovo        0.01          rbf
# 7                            ovo       0.001          rbf
# 8                            ovo      0.0001          rbf
# 9                            ovr        0.01          rbf
# 10                           ovr       0.001          rbf
# 11                           ovr      0.0001          rbf
# 12                           ovo        0.01          rbf
# 13                           ovo       0.001          rbf
# 14                           ovo      0.0001          rbf
# 15                           ovr        0.01          rbf
# 16                           ovr       0.001          rbf
# 17                           ovr      0.0001          rbf
# 18                           ovo        0.01          rbf
# 19                           ovo       0.001          rbf
# 20                           ovo      0.0001          rbf
# 21                           ovr        0.01          rbf
# 22                           ovr       0.001          rbf
# 23                           ovr      0.0001          rbf
# 24                           ovo         NaN       linear
# 25                           ovr         NaN       linear
# 26                           ovo         NaN       linear
# 27                           ovr         NaN       linear
# 28                           ovo         NaN       linear
# 29                           ovr         NaN       linear
# 30                           ovo         NaN       linear
# 31                           ovr         NaN       linear
#
#                                                params  split0_test_score  \
# 0   {'C': 1, 'decision_function_shape': 'ovo', 'ga...           0.622807
# 1   {'C': 1, 'decision_function_shape': 'ovo', 'ga...           0.929825
# 2   {'C': 1, 'decision_function_shape': 'ovo', 'ga...           0.903509
# 3   {'C': 1, 'decision_function_shape': 'ovr', 'ga...           0.622807
# 4   {'C': 1, 'decision_function_shape': 'ovr', 'ga...           0.929825
# 5   {'C': 1, 'decision_function_shape': 'ovr', 'ga...           0.903509
# 6   {'C': 10, 'decision_function_shape': 'ovo', 'g...           0.622807
# 7   {'C': 10, 'decision_function_shape': 'ovo', 'g...           0.894737
# 8   {'C': 10, 'decision_function_shape': 'ovo', 'g...           0.894737
# 9   {'C': 10, 'decision_function_shape': 'ovr', 'g...           0.622807
# 10  {'C': 10, 'decision_function_shape': 'ovr', 'g...           0.894737
# 11  {'C': 10, 'decision_function_shape': 'ovr', 'g...           0.894737
# 12  {'C': 100, 'decision_function_shape': 'ovo', '...           0.622807
# 13  {'C': 100, 'decision_function_shape': 'ovo', '...           0.894737
# 14  {'C': 100, 'decision_function_shape': 'ovo', '...           0.947368
# 15  {'C': 100, 'decision_function_shape': 'ovr', '...           0.622807
# 16  {'C': 100, 'decision_function_shape': 'ovr', '...           0.894737
# 17  {'C': 100, 'decision_function_shape': 'ovr', '...           0.947368
# 18  {'C': 1000, 'decision_function_shape': 'ovo', ...           0.622807
# 19  {'C': 1000, 'decision_function_shape': 'ovo', ...           0.894737
# 20  {'C': 1000, 'decision_function_shape': 'ovo', ...           0.938596
# 21  {'C': 1000, 'decision_function_shape': 'ovr', ...           0.622807
# 22  {'C': 1000, 'decision_function_shape': 'ovr', ...           0.894737
# 23  {'C': 1000, 'decision_function_shape': 'ovr', ...           0.938596
# 24  {'C': 1, 'decision_function_shape': 'ovo', 'ke...           0.947368
# 25  {'C': 1, 'decision_function_shape': 'ovr', 'ke...           0.947368
# 26  {'C': 10, 'decision_function_shape': 'ovo', 'k...           0.938596
# 27  {'C': 10, 'decision_function_shape': 'ovr', 'k...           0.938596
# 28  {'C': 100, 'decision_function_shape': 'ovo', '...           0.938596
# 29  {'C': 100, 'decision_function_shape': 'ovr', '...           0.938596
# 30  {'C': 1000, 'decision_function_shape': 'ovo', ...           0.947368
# 31  {'C': 1000, 'decision_function_shape': 'ovr', ...           0.947368
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.622807           0.631579           0.631579
# 1            0.921053           0.921053           0.947368
# 2            0.938596           0.938596           0.956140
# 3            0.622807           0.631579           0.631579
# 4            0.921053           0.921053           0.947368
# 5            0.938596           0.938596           0.956140
# 6            0.622807           0.631579           0.640351
# 7            0.903509           0.921053           0.938596
# 8            0.938596           0.947368           0.956140
# 9            0.622807           0.631579           0.640351
# 10           0.903509           0.921053           0.938596
# 11           0.938596           0.947368           0.956140
# 12           0.622807           0.631579           0.640351
# 13           0.903509           0.921053           0.938596
# 14           0.938596           0.956140           0.938596
# 15           0.622807           0.631579           0.640351
# 16           0.903509           0.921053           0.938596
# 17           0.938596           0.956140           0.938596
# 18           0.622807           0.631579           0.640351
# 19           0.903509           0.921053           0.938596
# 20           0.912281           0.938596           0.929825
# 21           0.622807           0.631579           0.640351
# 22           0.903509           0.921053           0.938596
# 23           0.912281           0.938596           0.929825
# 24           0.929825           0.973684           0.921053
# 25           0.929825           0.973684           0.921053
# 26           0.938596           0.973684           0.947368
# 27           0.938596           0.973684           0.947368
# 28           0.947368           0.973684           0.973684
# 29           0.947368           0.973684           0.973684
# 30           0.947368           0.973684           0.929825
# 31           0.947368           0.973684           0.929825
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.619469         0.625648        0.004993               31
# 1            0.893805         0.922621        0.017318               17
# 2            0.938053         0.934979        0.017169               11
# 3            0.619469         0.625648        0.004993               31
# 4            0.893805         0.922621        0.017318               17
# 5            0.938053         0.934979        0.017169               11
# 6            0.619469         0.627403        0.007619               25
# 7            0.884956         0.908570        0.019142               19
# 8            0.920354         0.931439        0.021841               13
# 9            0.619469         0.627403        0.007619               25
# 10           0.884956         0.908570        0.019142               19
# 11           0.920354         0.931439        0.021841               13
# 12           0.619469         0.627403        0.007619               25
# 13           0.884956         0.908570        0.019142               19
# 14           0.911504         0.938441        0.014957                9
# 15           0.619469         0.627403        0.007619               25
# 16           0.884956         0.908570        0.019142               19
# 17           0.911504         0.938441        0.014957                9
# 18           0.619469         0.627403        0.007619               25
# 19           0.884956         0.908570        0.019142               19
# 20           0.902655         0.924391        0.014507               15
# 21           0.619469         0.627403        0.007619               25
# 22           0.884956         0.908570        0.019142               19
# 23           0.902655         0.924391        0.014507               15
# 24           0.955752         0.945536        0.018689                7
# 25           0.955752         0.945536        0.018689                7
# 26           0.964602         0.952569        0.014200                5
# 27           0.964602         0.952569        0.014200                5
# 28           0.982301         0.963127        0.016974                1
# 29           0.982301         0.963127        0.016974                1
# 30           0.973451         0.954339        0.016957                3
# 31           0.973451         0.954339        0.016957                3

# %% [markdown]
# * It might be better to sort them in descending order of performance.

# %%
grid_search_results.sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 29      13.012354      6.133496         0.001773        0.000196     100
# 28      13.753024      2.014074         0.002387        0.000601     100
# 31      11.413814      8.383838         0.002977        0.001363    1000
# 30      13.373683      9.776557         0.002199        0.000617    1000
# 27       6.902102      1.274604         0.003198        0.000837      10
# 26       6.894012      1.496287         0.002854        0.000383      10
# 24       2.078829      0.843934         0.002588        0.000359       1
# 25       2.088413      0.840969         0.002672        0.000415       1
# 17       0.012243      0.000993         0.004748        0.000350     100
# 14       0.012212      0.000722         0.005215        0.000110     100
# 2        0.015840      0.001400         0.007788        0.000753       1
# 5        0.014390      0.000290         0.007980        0.000580       1
# 11       0.012509      0.001108         0.005321        0.000590      10
# 8        0.013677      0.001300         0.006487        0.001484      10
# 20       0.018306      0.003070         0.005644        0.000746    1000
# 23       0.018605      0.004129         0.005171        0.000307    1000
# 4        0.026748      0.002187         0.011573        0.001273       1
# 1        0.027807      0.001518         0.012188        0.002316       1
# 13       0.019349      0.000812         0.008924        0.000821     100
# 10       0.023679      0.000551         0.008479        0.001009      10
# 16       0.019701      0.001167         0.007717        0.001097     100
# 7        0.027339      0.001334         0.010299        0.001004      10
# 19       0.019858      0.001725         0.008760        0.000604    1000
# 22       0.021807      0.001404         0.008352        0.000756    1000
# 15       0.019521      0.000680         0.011933        0.000733     100
# 18       0.020977      0.000985         0.011823        0.000427    1000
# 12       0.019892      0.000899         0.011764        0.000419     100
# 9        0.027278      0.000304         0.012535        0.001342      10
# 6        0.032557      0.001228         0.016269        0.000680      10
# 21       0.023064      0.000410         0.013053        0.001162    1000
# 3        0.032065      0.001456         0.014848        0.000780       1
# 0        0.034367      0.002893         0.018493        0.003409       1
#
#    param_decision_function_shape param_gamma param_kernel  \
# 29                           ovr         NaN       linear
# 28                           ovo         NaN       linear
# 31                           ovr         NaN       linear
# 30                           ovo         NaN       linear
# 27                           ovr         NaN       linear
# 26                           ovo         NaN       linear
# 24                           ovo         NaN       linear
# 25                           ovr         NaN       linear
# 17                           ovr      0.0001          rbf
# 14                           ovo      0.0001          rbf
# 2                            ovo      0.0001          rbf
# 5                            ovr      0.0001          rbf
# 11                           ovr      0.0001          rbf
# 8                            ovo      0.0001          rbf
# 20                           ovo      0.0001          rbf
# 23                           ovr      0.0001          rbf
# 4                            ovr       0.001          rbf
# 1                            ovo       0.001          rbf
# 13                           ovo       0.001          rbf
# 10                           ovr       0.001          rbf
# 16                           ovr       0.001          rbf
# 7                            ovo       0.001          rbf
# 19                           ovo       0.001          rbf
# 22                           ovr       0.001          rbf
# 15                           ovr        0.01          rbf
# 18                           ovo        0.01          rbf
# 12                           ovo        0.01          rbf
# 9                            ovr        0.01          rbf
# 6                            ovo        0.01          rbf
# 21                           ovr        0.01          rbf
# 3                            ovr        0.01          rbf
# 0                            ovo        0.01          rbf
#
#                                                params  split0_test_score  \
# 29  {'C': 100, 'decision_function_shape': 'ovr', '...           0.938596
# 28  {'C': 100, 'decision_function_shape': 'ovo', '...           0.938596
# 31  {'C': 1000, 'decision_function_shape': 'ovr', ...           0.947368
# 30  {'C': 1000, 'decision_function_shape': 'ovo', ...           0.947368
# 27  {'C': 10, 'decision_function_shape': 'ovr', 'k...           0.938596
# 26  {'C': 10, 'decision_function_shape': 'ovo', 'k...           0.938596
# 24  {'C': 1, 'decision_function_shape': 'ovo', 'ke...           0.947368
# 25  {'C': 1, 'decision_function_shape': 'ovr', 'ke...           0.947368
# 17  {'C': 100, 'decision_function_shape': 'ovr', '...           0.947368
# 14  {'C': 100, 'decision_function_shape': 'ovo', '...           0.947368
# 2   {'C': 1, 'decision_function_shape': 'ovo', 'ga...           0.903509
# 5   {'C': 1, 'decision_function_shape': 'ovr', 'ga...           0.903509
# 11  {'C': 10, 'decision_function_shape': 'ovr', 'g...           0.894737
# 8   {'C': 10, 'decision_function_shape': 'ovo', 'g...           0.894737
# 20  {'C': 1000, 'decision_function_shape': 'ovo', ...           0.938596
# 23  {'C': 1000, 'decision_function_shape': 'ovr', ...           0.938596
# 4   {'C': 1, 'decision_function_shape': 'ovr', 'ga...           0.929825
# 1   {'C': 1, 'decision_function_shape': 'ovo', 'ga...           0.929825
# 13  {'C': 100, 'decision_function_shape': 'ovo', '...           0.894737
# 10  {'C': 10, 'decision_function_shape': 'ovr', 'g...           0.894737
# 16  {'C': 100, 'decision_function_shape': 'ovr', '...           0.894737
# 7   {'C': 10, 'decision_function_shape': 'ovo', 'g...           0.894737
# 19  {'C': 1000, 'decision_function_shape': 'ovo', ...           0.894737
# 22  {'C': 1000, 'decision_function_shape': 'ovr', ...           0.894737
# 15  {'C': 100, 'decision_function_shape': 'ovr', '...           0.622807
# 18  {'C': 1000, 'decision_function_shape': 'ovo', ...           0.622807
# 12  {'C': 100, 'decision_function_shape': 'ovo', '...           0.622807
# 9   {'C': 10, 'decision_function_shape': 'ovr', 'g...           0.622807
# 6   {'C': 10, 'decision_function_shape': 'ovo', 'g...           0.622807
# 21  {'C': 1000, 'decision_function_shape': 'ovr', ...           0.622807
# 3   {'C': 1, 'decision_function_shape': 'ovr', 'ga...           0.622807
# 0   {'C': 1, 'decision_function_shape': 'ovo', 'ga...           0.622807
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 29           0.947368           0.973684           0.973684
# 28           0.947368           0.973684           0.973684
# 31           0.947368           0.973684           0.929825
# 30           0.947368           0.973684           0.929825
# 27           0.938596           0.973684           0.947368
# 26           0.938596           0.973684           0.947368
# 24           0.929825           0.973684           0.921053
# 25           0.929825           0.973684           0.921053
# 17           0.938596           0.956140           0.938596
# 14           0.938596           0.956140           0.938596
# 2            0.938596           0.938596           0.956140
# 5            0.938596           0.938596           0.956140
# 11           0.938596           0.947368           0.956140
# 8            0.938596           0.947368           0.956140
# 20           0.912281           0.938596           0.929825
# 23           0.912281           0.938596           0.929825
# 4            0.921053           0.921053           0.947368
# 1            0.921053           0.921053           0.947368
# 13           0.903509           0.921053           0.938596
# 10           0.903509           0.921053           0.938596
# 16           0.903509           0.921053           0.938596
# 7            0.903509           0.921053           0.938596
# 19           0.903509           0.921053           0.938596
# 22           0.903509           0.921053           0.938596
# 15           0.622807           0.631579           0.640351
# 18           0.622807           0.631579           0.640351
# 12           0.622807           0.631579           0.640351
# 9            0.622807           0.631579           0.640351
# 6            0.622807           0.631579           0.640351
# 21           0.622807           0.631579           0.640351
# 3            0.622807           0.631579           0.631579
# 0            0.622807           0.631579           0.631579
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 29           0.982301         0.963127        0.016974                1
# 28           0.982301         0.963127        0.016974                1
# 31           0.973451         0.954339        0.016957                3
# 30           0.973451         0.954339        0.016957                3
# 27           0.964602         0.952569        0.014200                5
# 26           0.964602         0.952569        0.014200                5
# 24           0.955752         0.945536        0.018689                7
# 25           0.955752         0.945536        0.018689                7
# 17           0.911504         0.938441        0.014957                9
# 14           0.911504         0.938441        0.014957                9
# 2            0.938053         0.934979        0.017169               11
# 5            0.938053         0.934979        0.017169               11
# 11           0.920354         0.931439        0.021841               13
# 8            0.920354         0.931439        0.021841               13
# 20           0.902655         0.924391        0.014507               15
# 23           0.902655         0.924391        0.014507               15
# 4            0.893805         0.922621        0.017318               17
# 1            0.893805         0.922621        0.017318               17
# 13           0.884956         0.908570        0.019142               19
# 10           0.884956         0.908570        0.019142               19
# 16           0.884956         0.908570        0.019142               19
# 7            0.884956         0.908570        0.019142               19
# 19           0.884956         0.908570        0.019142               19
# 22           0.884956         0.908570        0.019142               19
# 15           0.619469         0.627403        0.007619               25
# 18           0.619469         0.627403        0.007619               25
# 12           0.619469         0.627403        0.007619               25
# 9            0.619469         0.627403        0.007619               25
# 6            0.619469         0.627403        0.007619               25
# 21           0.619469         0.627403        0.007619               25
# 3            0.619469         0.625648        0.004993               31
# 0            0.619469         0.625648        0.004993               31

# %% [markdown]
# * If we want the best performance directly:

# %%
grid_search.best_score_
# Out:
# 0.9631268436578171

# %% [markdown]
# * As before, we can also test with a `SGDClassifier`.
#
# * We will start with a different approach.
#
# * Instead of exhausting all possible combinations in the search, we will randomly sample between them.

# %%
param_dist = {
    "average": [True, False],
    "l1_ratio": stats.uniform(0, 1),
    "alpha": stats.loguniform(1e-2, 1e0),
}

# %% [markdown]
# * To do this, we use the `RandomizedSearchCV` class by giving the number of samples we want it to try from the space of possible combinations of the parameters.

# %%
clf = SGDClassifier()
random_search = RandomizedSearchCV(clf, param_distributions=param_dist, n_iter=15, n_jobs=-1)
random_search.fit(bc.data, bc.target)
# Out:
# RandomizedSearchCV(estimator=SGDClassifier(), n_iter=15, n_jobs=-1,
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_frozen object at 0x13577f1c0>,
#                                         'average': [True, False],
#                                         'l1_ratio': <scipy.stats._distn_infrastructure.rv_frozen object at 0x135758f70>})

# %% [markdown]
# * To see what we found:

# %%
random_search.best_params_
# Out:
# {'alpha': 0.3664163569482923,
#  'average': False,
#  'l1_ratio': 0.15413448344948555}

# %% [markdown]
# * And the optimal estimator:

# %%
random_search.best_estimator_
# Out:
# SGDClassifier(alpha=0.3664163569482923, l1_ratio=0.15413448344948555)

# %% [markdown]
# * And how good this is:

# %%
random_search.best_score_
# Out:
# 0.912125446359261

# %% [markdown]
# * If we want (and can) do an exhaustive price search, of course we proceed as before:

# %%
param_grid = {
    "average": [True, False],
    "l1_ratio": np.linspace(0, 1, num=10),
    "alpha": np.power(10, np.arange(-2, 1, dtype=float)),
}

# %% [markdown]
# * Again we use the `GridSearchCV` class.

# %%
clf = SGDClassifier()
grid_search = GridSearchCV(clf, param_grid=param_grid, n_jobs=-1)
grid_search.fit(bc.data, bc.target)
# Out:
# GridSearchCV(estimator=SGDClassifier(), n_jobs=-1,
#              param_grid={'alpha': array([0.01, 0.1 , 1.  ]),
#                          'average': [True, False],
#                          'l1_ratio': array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])})

# %% [markdown]
# * To see what we found:

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.01, 'average': False, 'l1_ratio': 0.0}

# %% [markdown]
# * And the best appraiser:

# %%
grid_search.best_estimator_
# Out:
# SGDClassifier(alpha=0.01, l1_ratio=0.0)

# %% [markdown]
# * And its performance:

# %%
grid_search.best_score_
# Out:
# 0.9155721161310355

# %% [markdown]
# * But shouldn't we also try normalization?
#
# * So we will make a pipeline.

# %%
clf = make_pipeline(StandardScaler(), SGDClassifier())

# %% [markdown]
# * We can define parameters to search for each of the steps of a pipeline.
#
# * Here we will only give for the second.

# %%
param_grid = {
    "sgdclassifier__average": [True, False],
    "sgdclassifier__l1_ratio": np.linspace(0, 1, num=10),
    "sgdclassifier__alpha": np.power(10, np.arange(-2, 1, dtype=float)),
}

# %% [markdown]
# * So we proceed to the search...

# %%
grid_search = GridSearchCV(clf, param_grid=param_grid, n_jobs=-1)
grid_search.fit(bc.data, bc.target)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('sgdclassifier', SGDClassifier())]),
#              n_jobs=-1,
#              param_grid={'sgdclassifier__alpha': array([0.01, 0.1 , 1.  ]),
#                          'sgdclassifier__average': [True, False],
#                          'sgdclassifier__l1_ratio': array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])})

# %% [markdown]
# * And here's what we got:

# %%
grid_search.best_params_
# Out:
# {'sgdclassifier__alpha': 0.01,
#  'sgdclassifier__average': True,
#  'sgdclassifier__l1_ratio': 0.7777777777777777}

# %% [markdown]
# * The best estimator:

# %%
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdclassifier',
#                  SGDClassifier(alpha=0.01, average=True,
#                                l1_ratio=0.7777777777777777))])

# %% [markdown]
# * And the best performance:

# %%
grid_search.best_score_
# Out:
# 0.9806707033069401
